# %%
import cv2
import matplotlib.pyplot as plt


logo = cv2.imread("frog.jpg")
messi = cv2.imread("messi.jpg")

rows, cols, _ = logo.shape
roi = messi[0 : rows, 0: cols] # 取到的是梅西的左上角部分

# thresholding
img2gray = cv2.cvtColor(logo, cv2.COLOR_BGR2GRAY)

ret, mask = cv2.threshold(img2gray, 200, 255, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)
plt.subplot(1, 2, 1)
plt.imshow(mask, "gray")
plt.subplot(1, 2, 2)
plt.imshow(mask_inv, "gray")

image(0-1) & mask(0 or 1)


img_bg = cv2.bitwise_and(roi, logo, mask = mask)
img_fg = cv2.bitwise_and(logo, logo, mask = mask_inv)
